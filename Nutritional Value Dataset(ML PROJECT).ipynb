# %% [markdown]
# # CASE STUDY OF ML : NUTRITIONAL VALUE DATASET

# %%
print(("*")*125)
print(" \t\t\t\t************** DATASET:- NUTRITIONAL VALUE DATASET ***************\n\nINTRODUCTION :- Welcome, To the Nutritional Value Dashboard, a comprehensive analysis of fast-food chain companies offering a diverse range of foods.The Nutritional Value Dataset contains a more than 500 foods each with the amount of Carbohydrates, Fats, Proteins, Saturated Fats, Sugar, Fibers, Energy, etc. and labelled for each food. Also, the foods are categorised into various groups like Desserts, Vegetables, Breakfast items or more.Here, We Analyze the idea of the Nutritional content of foods of this Companies. With this dataset, We can learn about nutrients in food and how they contribute to our overall health. and also can be used to help people make better choices about the food they eat.\n\nOBJECTIVE:- This machine learning project focuses on predicting the nutritional composition of fast-food items. By developing accurate models, it aims to analyze nutrient levels, identify company-specific patterns, categorize meals, explore nutrient correlations, and determine key features influencing nutritional content. The goal is to create a user-friendly interface for real-time predictions, continually improve models, and provide educational insights for informed dietary choices in the fast-food landscape.")
print(("*")*125)
# Out:
# *****************************************************************************************************************************
#  				************** DATASET:- NUTRITIONAL VALUE DATASET ***************
#
# INTRODUCTION :- Welcome, To the Nutritional Value Dashboard, a comprehensive analysis of fast-food chain companies offering a diverse range of foods.The Nutritional Value Dataset contains a more than 500 foods each with the amount of Carbohydrates, Fats, Proteins, Saturated Fats, Sugar, Fibers, Energy, etc. and labelled for each food. Also, the foods are categorised into various groups like Desserts, Vegetables, Breakfast items or more.Here, We Analyze the idea of the Nutritional content of foods of this Companies. With this dataset, We can learn about nutrients in food and how they contribute to our overall health. and also can be used to help people make better choices about the food they eat.
#
# OBJECTIVE:- This machine learning project focuses on predicting the nutritional composition of fast-food items. By developing accurate models, it aims to analyze nutrient levels, identify company-specific patterns, categorize meals, explore nutrient correlations, and determine key features influencing nutritional content. The goal is to create a user-friendly interface for real-time predictions, continually improve models, and provide educational insights for informed dietary choices in the fast-food landscape.
# *****************************************************************************************************************************

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Nutritional value dataset.csv")
df
# Out:
#        Company   Category                           Product Per Serve Size  \
# 0    Pizza Hut  All Meals          Corn n Cheese (Personal)        143.5 g
# 1    Pizza Hut  All Meals          Country Feast (Personal)          178 g
# 2    Pizza Hut  All Meals          Double Cheese (Personal)          143 g
# 3    Pizza Hut  All Meals  Double Paneer Supreme (Personal)        174.5 g
# 4    Pizza Hut  All Meals          Farmer`s Pick (Personal)          177 g
# ..         ...        ...                               ...            ...
# 525    Dominos  All Meals                    CHICKEN WINGS             174
# 526    Dominos  All Meals            CRISPY CHICKEN STRIPS             156
# 527    Dominos  All Meals             ZINGY PARCEL CHICKEN             210
# 528    Dominos  All Meals          TACO MEXICANA - CHICKEN              97
# 529    Dominos  All Meals        CALZONE POCKETS - CHICKEN             248
#
#      Energy (kCal)  Carbohydrates (g)  Protein (g)  Fiber (g)  Sugar (g)  \
# 0           432.60              65.64        17.91       3.85        0.0
# 1           407.60              67.11        16.73       7.19        0.0
# 2           423.33              59.97        18.26       3.49        0.0
# 3           474.03              52.86        20.07       3.79        0.0
# 4           408.16              53.93        19.91       2.46        0.0
# ..             ...                ...          ...        ...        ...
# 525         352.90              24.50        35.30       5.76       10.4
# 526         461.20              51.30        26.70       5.16        3.6
# 527         667.50              17.30        19.20      16.92       10.6
# 528         322.60              34.20         9.30       5.40        3.9
# 529         582.90             101.00        18.60       5.04       12.2
#
#      Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  \
# 0            10.93               5.14           0.16             16.19
# 1             8.03               3.24           0.11             66.80
# 2            12.27               5.23           0.18             19.75
# 3            20.26               9.25           0.33             71.72
# 4            12.53               4.90           0.14             48.09
# ..             ...                ...            ...               ...
# 525          12.60               4.80           0.19            308.70
# 526          13.90               4.30           0.17            713.07
# 527          31.30              14.10           0.56            541.49
# 528          16.50               4.50           0.18            564.30
# 529          11.60               4.20           0.17           1171.60
#
#      Sodium (mg)
# 0         499.72
# 1         818.00
# 2         638.22
# 3        1128.11
# 4         942.67
# ..           ...
# 525          NaN
# 526          NaN
# 527          NaN
# 528          NaN
# 529          NaN
#
# [530 rows x 14 columns]

# %% [markdown]
# # BASIC INFORMATION OF DATASET

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            530 non-null    object
#  1   Category           530 non-null    object
#  2   Product            530 non-null    object
#  3   Per Serve Size     530 non-null    object
#  4   Energy (kCal)      530 non-null    float64
#  5   Carbohydrates (g)  530 non-null    float64
#  6   Protein (g)        530 non-null    float64
#  7   Fiber (g)          530 non-null    float64
#  8   Sugar (g)          530 non-null    float64
#  9   Total Fat (g)      530 non-null    float64
#  10  Saturated Fat (g)  530 non-null    float64
#  11  Trans Fat (g)      530 non-null    float64
#  12  Cholesterol (mg)   530 non-null    float64
#  13  Sodium (mg)        443 non-null    float64
# dtypes: float64(10), object(4)
# memory usage: 58.1+ KB

# %% [markdown]
# # UNDERSTANDING THE DATASET

# %%
df.columns
# Out:
# Index(['Company', 'Category', 'Product', 'Per Serve Size', 'Energy (kCal)',
#        'Carbohydrates (g)', 'Protein (g)', 'Fiber (g)', 'Sugar (g)',
#        'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)'],
#       dtype='object')

# %%
print(" \t\t\t\t********************COLUMNS REPRESENTATION*********************")

print("(a) Company : Name of the Fast Food Company.\n\n(b) Category : The category of the meal.\n\n(c) Product : Name of the Meal.\n\n(d) Per Serve Size : Quantity of the Meal Served.\n\n(e) Energy (kCal) : Energy from the Meal in Kilo Calories.\n\n(f) Carbohydrates (g) : Carbohydrates obtained from the Meal in grams.\n\n(g) Protein (g) : Proteins obtained from the Meal in grams.\n\n(h) Fiber (g) : Fibers obtained from the Meal in grams.\n\n(i) Sugar (g) : Sugars obtained from the Meal in grams.\n\n(j) Total Fat (g) : Total Fats obtained from the Meal in grams.\n\n(k) Saturated Fat (g) : Saturated Fats obtained from the Meal in grams.\n\n(l) Trans Fat (g) : Trans Fat obtained from the Meal in grams.\n\n(m) Cholesterol (mg) : Cholesterol obtained from the Meal in grams.\n\n(n) Sodium (mg) : Sodium obtained from the Meal in grams.")
print(("*")*120)
# Out:
#  				********************COLUMNS REPRESENTATION*********************
# (a) Company : Name of the Fast Food Company.
#
# (b) Category : The category of the meal.
#
# (c) Product : Name of the Meal.
#
# (d) Per Serve Size : Quantity of the Meal Served.
#
# (e) Energy (kCal) : Energy from the Meal in Kilo Calories.
#
# (f) Carbohydrates (g) : Carbohydrates obtained from the Meal in grams.
#
# (g) Protein (g) : Proteins obtained from the Meal in grams.
#
# (h) Fiber (g) : Fibers obtained from the Meal in grams.
#
# (i) Sugar (g) : Sugars obtained from the Meal in grams.
#
# (j) Total Fat (g) : Total Fats obtained from the Meal in grams.
#
# (k) Saturated Fat (g) : Saturated Fats obtained from the Meal in grams.
#
# (l) Trans Fat (g) : Trans Fat obtained from the Meal in grams.
#
# (m) Cholesterol (mg) : Cholesterol obtained from the Meal in grams.
#
# (n) Sodium (mg) : Sodium obtained from the Meal in grams.
# ************************************************************************************************************************

# %% [markdown]
# ## UNIVARIATE AND BIVARIATE ANALYSIS OF DATASET

# %%
Company_counts = df['Company'].value_counts()
print(df['Company'].value_counts())

plt.figure(figsize=(8, 6))
Company_counts.plot(kind='bar')
plt.title('Distribution of Companies by Category')
plt.xlabel('Company')
plt.ylabel('Category')
plt.xticks(rotation=90)
plt.show()

print(("*")*125)
print("\t\t\t\t**************ANALYSIS***************\n\nThe bar plot represents that no. of Categories Company wise. Also Observing that Pizza hut has more categories of foods and after that MacDonald, Dominos, KFC, etc.")
print(("*")*125)
# Out:
# Pizza Hut      144
# McDonalds      140
# Dominos         87
# KFC             72
# Starbucks       46
# Burger King     41
# Name: Company, dtype: int64
# *****************************************************************************************************************************
# 				**************ANALYSIS***************
#
# The bar plot represents that no. of Categories Company wise. Also Observing that Pizza hut has more categories of foods and after that MacDonald, Dominos, KFC, etc.
# *****************************************************************************************************************************

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Energy (kCal)'], df['Protein (g)'], color='green', alpha=0.5)
plt.title('Energy (kCal) vs. Protein (g)')
plt.xlabel('Energy (kCal)')
plt.ylabel('Protein (g)')
plt.grid()
plt.show()

print(("*")*125)
print("\t\t\t\t**************ANALYSIS***************\n\nThis is representing the Positive correlation between the Energy and Proteins of the products. here, observe that when Amount of Protein are increases then its Energy also increases.")
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 				**************ANALYSIS***************
#
# This is representing the Positive correlation between the Energy and Proteins of the products. here, observe that when Amount of Protein are increases then its Energy also increases.
# *****************************************************************************************************************************

# %% [markdown]
# # CLEANING DATA

# %% [markdown]
# # Finding null/missing values in the data if any.¶

# %%
df.isnull().sum()
# Out:
# Company               0
# Category              0
# Product               0
# Per Serve Size        0
# Energy (kCal)         0
# Carbohydrates (g)     0
# Protein (g)           0
# Fiber (g)             0
# Sugar (g)             0
# Total Fat (g)         0
# Saturated Fat (g)     0
# Trans Fat (g)         0
# Cholesterol (mg)      0
# Sodium (mg)          87
# dtype: int64

# %%
df["Sodium (mg)"]=df["Sodium (mg)"].fillna(df["Sodium (mg)"].mean())

# %%
(df["Fiber (g)"]=='inf').replace(df["Fiber (g)"].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 0 to 529
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            530 non-null    object
#  1   Category           530 non-null    object
#  2   Product            530 non-null    object
#  3   Per Serve Size     530 non-null    object
#  4   Energy (kCal)      530 non-null    float64
#  5   Carbohydrates (g)  530 non-null    float64
#  6   Protein (g)        530 non-null    float64
#  7   Fiber (g)          530 non-null    float64
#  8   Sugar (g)          530 non-null    float64
#  9   Total Fat (g)      530 non-null    float64
#  10  Saturated Fat (g)  530 non-null    float64
#  11  Trans Fat (g)      530 non-null    float64
#  12  Cholesterol (mg)   530 non-null    float64
#  13  Sodium (mg)        530 non-null    float64
# dtypes: float64(10), object(4)
# memory usage: 58.1+ KB

# %% [markdown]
# # STATISTICAL INFORMATION OF DATASET

# %%
df.describe()
# Out:
#        Energy (kCal)  Carbohydrates (g)  Protein (g)   Fiber (g)   Sugar (g)  \
# count     530.000000         530.000000   530.000000  530.000000  530.000000
# mean      377.304470          39.442302    16.710340    4.688287    8.276226
# std       338.315722          21.196943    24.425784    5.657098   12.186627
# min         0.000000           0.000000     0.000000    0.000000    0.000000
# 25%       180.750000          24.227500     5.000000    1.690000    0.000000
# 50%       329.645000          38.570000    11.445000    3.000000    3.200000
# 75%       451.812500          54.120000    20.005000    5.702500    9.850000
# max      2880.000000         137.800000   203.000000   45.000000   64.220000
#
#        Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  \
# count     530.000000         530.000000     530.000000        530.000000
# mean       13.228528           5.946302       0.279443        118.620434
# std        10.740934           4.844024       3.265604        502.865434
# min         0.000000           0.000000       0.000000          0.000000
# 25%         5.000000           2.500000       0.030000          9.462500
# 50%        12.600000           5.240000       0.110000         30.085000
# 75%        18.360000           8.095000       0.207500         77.535000
# max        82.600000          33.000000      75.260000       9769.700000
#
#        Sodium (mg)
# count   530.000000
# mean    422.431578
# std     430.805073
# min       0.000000
# 25%      14.135000
# 50%     422.431578
# 75%     679.650000
# max    2399.490000

# %%
df.corr()
# Out:
#                    Energy (kCal)  Carbohydrates (g)  Protein (g)  Fiber (g)  \
# Energy (kCal)           1.000000           0.429223     0.895195   0.657127
# Carbohydrates (g)       0.429223           1.000000     0.180120   0.270523
# Protein (g)             0.895195           0.180120     1.000000   0.587107
# Fiber (g)               0.657127           0.270523     0.587107   1.000000
# Sugar (g)              -0.196478           0.074505    -0.275107  -0.315508
# Total Fat (g)           0.797403           0.444378     0.668889   0.565528
# Saturated Fat (g)       0.676308           0.429842     0.527750   0.566105
# Trans Fat (g)           0.007013          -0.069852     0.014551  -0.015478
# Cholesterol (mg)        0.178290           0.080357     0.264389   0.069781
# Sodium (mg)             0.109807           0.423317     0.013667  -0.116285
#
#                    Sugar (g)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# Energy (kCal)      -0.196478       0.797403           0.676308       0.007013
# Carbohydrates (g)   0.074505       0.444378           0.429842      -0.069852
# Protein (g)        -0.275107       0.668889           0.527750       0.014551
# Fiber (g)          -0.315508       0.565528           0.566105      -0.015478
# Sugar (g)           1.000000      -0.267404          -0.152495      -0.027869
# Total Fat (g)      -0.267404       1.000000           0.873274       0.070196
# Saturated Fat (g)  -0.152495       0.873274           1.000000      -0.041473
# Trans Fat (g)      -0.027869       0.070196          -0.041473       1.000000
# Cholesterol (mg)   -0.065155       0.334136           0.292933      -0.010696
# Sodium (mg)        -0.311964       0.272286           0.181214       0.095069
#
#                    Cholesterol (mg)  Sodium (mg)
# Energy (kCal)              0.178290     0.109807
# Carbohydrates (g)          0.080357     0.423317
# Protein (g)                0.264389     0.013667
# Fiber (g)                  0.069781    -0.116285
# Sugar (g)                 -0.065155    -0.311964
# Total Fat (g)              0.334136     0.272286
# Saturated Fat (g)          0.292933     0.181214
# Trans Fat (g)             -0.010696     0.095069
# Cholesterol (mg)           1.000000    -0.076503
# Sodium (mg)               -0.076503     1.000000

# %% [markdown]
# # Separating into Features and Target Coulmns

# %%
x=df.drop(columns=['Energy (kCal)'])
x
# Out:
#        Company   Category                           Product Per Serve Size  \
# 0    Pizza Hut  All Meals          Corn n Cheese (Personal)        143.5 g
# 1    Pizza Hut  All Meals          Country Feast (Personal)          178 g
# 2    Pizza Hut  All Meals          Double Cheese (Personal)          143 g
# 3    Pizza Hut  All Meals  Double Paneer Supreme (Personal)        174.5 g
# 4    Pizza Hut  All Meals          Farmer`s Pick (Personal)          177 g
# ..         ...        ...                               ...            ...
# 525    Dominos  All Meals                    CHICKEN WINGS             174
# 526    Dominos  All Meals            CRISPY CHICKEN STRIPS             156
# 527    Dominos  All Meals             ZINGY PARCEL CHICKEN             210
# 528    Dominos  All Meals          TACO MEXICANA - CHICKEN              97
# 529    Dominos  All Meals        CALZONE POCKETS - CHICKEN             248
#
#      Carbohydrates (g)  Protein (g)  Fiber (g)  Sugar (g)  Total Fat (g)  \
# 0                65.64        17.91       3.85        0.0          10.93
# 1                67.11        16.73       7.19        0.0           8.03
# 2                59.97        18.26       3.49        0.0          12.27
# 3                52.86        20.07       3.79        0.0          20.26
# 4                53.93        19.91       2.46        0.0          12.53
# ..                 ...          ...        ...        ...            ...
# 525              24.50        35.30       5.76       10.4          12.60
# 526              51.30        26.70       5.16        3.6          13.90
# 527              17.30        19.20      16.92       10.6          31.30
# 528              34.20         9.30       5.40        3.9          16.50
# 529             101.00        18.60       5.04       12.2          11.60
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)
# 0                 5.14           0.16             16.19   499.720000
# 1                 3.24           0.11             66.80   818.000000
# 2                 5.23           0.18             19.75   638.220000
# 3                 9.25           0.33             71.72  1128.110000
# 4                 4.90           0.14             48.09   942.670000
# ..                 ...            ...               ...          ...
# 525               4.80           0.19            308.70   422.431578
# 526               4.30           0.17            713.07   422.431578
# 527              14.10           0.56            541.49   422.431578
# 528               4.50           0.18            564.30   422.431578
# 529               4.20           0.17           1171.60   422.431578
#
# [530 rows x 13 columns]

# %%
y=df.iloc[:,4]
y
# Out:
# 0      432.60
# 1      407.60
# 2      423.33
# 3      474.03
# 4      408.16
#         ...
# 525    352.90
# 526    461.20
# 527    667.50
# 528    322.60
# 529    582.90
# Name: Energy (kCal), Length: 530, dtype: float64

# %% [markdown]
# # HANDELLING OUTLIERS

# %%
df["Category"].unique()
# Out:
# array(['All Meals', 'Hot Breakfast', 'Cookies, Brownies & Bars',
#        'Croissants, Danishes & Bagels',
#        'Loaves, Coffee Cakes & Cake Pops', 'Seasonal Bakery Offerings',
#        'Fruit & Yogurt', 'REGULAR MENU', 'BREAKFAST MENU', 'McCAFE MENU',
#        'DESSERTS MENU', 'GOURMET MENU', 'CONDIMENTS MENU'], dtype=object)

# %%
sns.boxplot(data=x,x=y)
# Out:
# <Axes: xlabel='Energy (kCal)'>

# %%
sns.boxplot(data=x,x=y,y='Category')
plt.grid()

# %%
i=x[(x.Category=='McCAFE MENU') & (y>450)].index
x.drop(i,axis=0,inplace=True)
y.drop(i,axis=0,inplace=True)

i=x[(x.Category=='BREAKFAST MENU') & (y>300)].index
x.drop(i,axis=0,inplace=True)
y.drop(i,axis=0,inplace=True)

i=x[(x.Category=='REGULAR MENU') & (y>500)].index
x.drop(i,axis=0,inplace=True)
y.drop(i,axis=0,inplace=True)

i=x[(x.Category=='All Meals') & (y>=900)].index
x.drop(i,axis=0,inplace=True)
y.drop(i,axis=0,inplace=True)

# %%
sns.boxplot(data=x,x=y,y='Category')
plt.grid()

# %% [markdown]
# # HANDELLING SKEWNESS

# %%
col=x.select_dtypes(['int','float']).columns
col
# Out:
# Index(['Carbohydrates (g)', 'Protein (g)', 'Fiber (g)', 'Sugar (g)',
#        'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)'],
#       dtype='object')

# %%
x[col]
# Out:
#      Carbohydrates (g)  Protein (g)  Fiber (g)  Sugar (g)  Total Fat (g)  \
# 0                65.64        17.91       3.85        0.0          10.93
# 1                67.11        16.73       7.19        0.0           8.03
# 2                59.97        18.26       3.49        0.0          12.27
# 3                52.86        20.07       3.79        0.0          20.26
# 4                53.93        19.91       2.46        0.0          12.53
# ..                 ...          ...        ...        ...            ...
# 525              24.50        35.30       5.76       10.4          12.60
# 526              51.30        26.70       5.16        3.6          13.90
# 527              17.30        19.20      16.92       10.6          31.30
# 528              34.20         9.30       5.40        3.9          16.50
# 529             101.00        18.60       5.04       12.2          11.60
#
#      Saturated Fat (g)  Trans Fat (g)  Cholesterol (mg)  Sodium (mg)
# 0                 5.14           0.16             16.19   499.720000
# 1                 3.24           0.11             66.80   818.000000
# 2                 5.23           0.18             19.75   638.220000
# 3                 9.25           0.33             71.72  1128.110000
# 4                 4.90           0.14             48.09   942.670000
# ..                 ...            ...               ...          ...
# 525               4.80           0.19            308.70   422.431578
# 526               4.30           0.17            713.07   422.431578
# 527              14.10           0.56            541.49   422.431578
# 528               4.50           0.18            564.30   422.431578
# 529               4.20           0.17           1171.60   422.431578
#
# [496 rows x 9 columns]

# %%
from scipy.stats import skew

# %%
skew(x['Carbohydrates (g)'])
# Out:
# 0.19005035587527114

# %%
for i in x[col]:
    print(i)
    print(skew(x[i]))
    
    plt.figure()
    sns.displot(x[i])
    plt.show()
# Out:
# Carbohydrates (g)
# 0.19005035587527114
# Protein (g)
# 2.5540267170947355
# Fiber (g)
# 3.9494879220984904
# Sugar (g)
# 1.8130275244209553
# Total Fat (g)
# 0.6314509099038365
# Saturated Fat (g)
# 1.3175074314559376
# Trans Fat (g)
# 22.154382534283517
# Cholesterol (mg)
# 6.499744889880286
# Sodium (mg)
# 0.9856142012782041

# %%
pd.concat([x,y],axis=1).corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_eb3cf_row0_col0, #T_eb3cf_row1_col1, #T_eb3cf_row2_col2, #T_eb3cf_row3_col3, #T_eb3cf_row4_col4, #T_eb3cf_row5_col5, #T_eb3cf_row6_col6, #T_eb3cf_row7_col7, #T_eb3cf_row8_col8, #T_eb3cf_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col1, #T_eb3cf_row2_col9, #T_eb3cf_row4_col0, #T_eb3cf_row8_col4 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col2 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col3 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_eb3cf_row0_col4 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col5 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col6, #T_eb3cf_row1_col3, #T_eb3cf_row3_col1, #T_eb3cf_row3_col2, #T_eb3cf_row3_col4, #T_eb3cf_row3_col5, #T_eb3cf_row3_col7, #T_eb3cf_row3_col8, #T_eb3cf_row3_col9, #T_eb3cf_row6_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_eb3cf_row0_col7, #T_eb3cf_row7_col0, #T_eb3cf_row8_col2 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_eb3cf_row0_col8 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_eb3cf_row0_col9 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_eb3cf_row1_col0 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_eb3cf_row1_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_eb3cf_row1_col4 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_eb3cf_row1_col5 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_eb3cf_row1_col6 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_eb3cf_row1_col7 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_eb3cf_row1_col8, #T_eb3cf_row4_col2 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_eb3cf_row1_col9 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_eb3cf_row2_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_eb3cf_row2_col1, #T_eb3cf_row2_col4 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_eb3cf_row2_col3 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_eb3cf_row2_col5 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_eb3cf_row2_col6, #T_eb3cf_row6_col7, #T_eb3cf_row7_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_eb3cf_row2_col7 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_eb3cf_row2_col8 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_eb3cf_row3_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_eb3cf_row3_col6 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_eb3cf_row4_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_eb3cf_row4_col3, #T_eb3cf_row6_col5 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_eb3cf_row4_col5 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_eb3cf_row4_col6, #T_eb3cf_row8_col6 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_eb3cf_row4_col7 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_eb3cf_row4_col8 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_eb3cf_row4_col9 {
#   background-color: #045a8d;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col1 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col2 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col3 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_eb3cf_row5_col4 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col6 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_eb3cf_row5_col7, #T_eb3cf_row6_col8, #T_eb3cf_row9_col7 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_eb3cf_row5_col8 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_eb3cf_row5_col9 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_eb3cf_row6_col1 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_eb3cf_row6_col2 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_eb3cf_row6_col3 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_eb3cf_row6_col4 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_eb3cf_row6_col9 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_eb3cf_row7_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_eb3cf_row7_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_eb3cf_row7_col3 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_eb3cf_row7_col4 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_eb3cf_row7_col5 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_eb3cf_row7_col8 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_eb3cf_row7_col9 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_eb3cf_row8_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_eb3cf_row8_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_eb3cf_row8_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_eb3cf_row8_col5 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_eb3cf_row8_col7 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_eb3cf_row8_col9 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col0 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col1 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col2 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col3 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_eb3cf_row9_col4 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col5 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_eb3cf_row9_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_eb3cf_row9_col8 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb3cf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb3cf_level0_col0" class="col_heading level0 col0" >Carbohydrates (g)</th>
#       <th id="T_eb3cf_level0_col1" class="col_heading level0 col1" >Protein (g)</th>
#       <th id="T_eb3cf_level0_col2" class="col_heading level0 col2" >Fiber (g)</th>
#       <th id="T_eb3cf_level0_col3" class="col_heading level0 col3" >Sugar (g)</th>
#       <th id="T_eb3cf_level0_col4" class="col_heading level0 col4" >Total Fat (g)</th>
#       <th id="T_eb3cf_level0_col5" class="col_heading level0 col5" >Saturated Fat (g)</th>
#       <th id="T_eb3cf_level0_col6" class="col_heading level0 col6" >Trans Fat (g)</th>
#       <th id="T_eb3cf_level0_col7" class="col_heading level0 col7" >Cholesterol (mg)</th>
#       <th id="T_eb3cf_level0_col8" class="col_heading level0 col8" >Sodium (mg)</th>
#       <th id="T_eb3cf_level0_col9" class="col_heading level0 col9" >Energy (kCal)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb3cf_level0_row0" class="row_heading level0 row0" >Carbohydrates (g)</th>
#       <td id="T_eb3cf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_eb3cf_row0_col1" class="data row0 col1" >0.379286</td>
#       <td id="T_eb3cf_row0_col2" class="data row0 col2" >0.336699</td>
#       <td id="T_eb3cf_row0_col3" class="data row0 col3" >0.070922</td>
#       <td id="T_eb3cf_row0_col4" class="data row0 col4" >0.520975</td>
#       <td id="T_eb3cf_row0_col5" class="data row0 col5" >0.477955</td>
#       <td id="T_eb3cf_row0_col6" class="data row0 col6" >-0.073052</td>
#       <td id="T_eb3cf_row0_col7" class="data row0 col7" >0.179269</td>
#       <td id="T_eb3cf_row0_col8" class="data row0 col8" >0.439178</td>
#       <td id="T_eb3cf_row0_col9" class="data row0 col9" >0.793725</td>
#     </tr>
#     <tr>
#       <th id="T_eb3cf_level0_row1" class="row_heading level0 row1" >Protein (g)</th>
#       <td id="T_eb3cf_row1_col0" class="data row1 col0" >0.379286</td>
#       <td id="T_eb3cf_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_eb3cf_row1_col2" class="data row1 col2" >0.372997</td>
#       <td id="T_eb3cf_row1_col3" class="data row1 col3" >-0.382054</td>
#       <td id="T_eb3cf_row1_col4" class="data row1 col4" >0.632275</td>
#       <td id="T_eb3cf_row1_col5" class="data row1 col5" >0.459876</td>
#       <td id="T_eb3cf_row1_col6" class="data row1 col6" >0.058448</td>
#       <td id="T_eb3cf_row1_col7" class="data row1 col7" >0.309280</td>
#       <td id="T_eb3cf_row1_col8" class="data row1

# %%
x['Trans Fat (g)']=np.log(x['Trans Fat (g)'])

# %%
skew(x['Trans Fat (g)'])
# Out:
# nan

# %%
x.drop(['Company','Category','Product','Per Serve Size'], axis=1, inplace=True)

# %%
x["Protein (g)"] = x["Protein (g)"].astype(int)

x["Carbohydrates (g)"] = x["Carbohydrates (g)"].astype(int)

x["Fiber (g)"] = x["Fiber (g)"].astype(int)

x["Sugar (g)"] = x["Sugar (g)"].astype(int)

x["Total Fat (g)"] = x["Total Fat (g)"].astype(int)

x["Saturated Fat (g)"] = x["Saturated Fat (g)"].astype(int)

x['Sodium (mg)'] = x['Sodium (mg)'].astype(int)

# %%
x.drop('Cholesterol (mg)', axis=1, inplace=True)
x.drop('Trans Fat (g)', axis=1, inplace=True)

# %%
x.fillna(x.mean(), inplace=True)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 496 entries, 0 to 529
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Carbohydrates (g)  496 non-null    int32
#  1   Protein (g)        496 non-null    int32
#  2   Fiber (g)          496 non-null    int32
#  3   Sugar (g)          496 non-null    int32
#  4   Total Fat (g)      496 non-null    int32
#  5   Saturated Fat (g)  496 non-null    int32
#  6   Sodium (mg)        496 non-null    int32
# dtypes: int32(7)
# memory usage: 17.4 KB

# %% [markdown]
# # Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=1)

# %% [markdown]
# ## 1 - Predicting the data using Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)
ypred=lr.predict(xtest)

# %%
ypred
# Out:
# array([595.68248655, 274.27452872,  82.59525977, 125.04581826,
#        264.45001435, 350.93824389, 150.2660173 , 330.11044348,
#        183.73014781, 638.25451885, 360.47067494,  60.21629865,
#        592.59135786, 561.9673156 , 546.12090978,  84.35236088,
#        366.07712693, 239.23768558, 161.5910536 , 260.09230839,
#        230.34221721,  32.91589585, 548.61240783, 406.40107508,
#        143.34037082, 132.47080896, 477.54251366, 138.37156021,
#        532.5966091 , 314.41619137, 179.62049631, 228.393134  ,
#        216.03550926, 199.94112834, 236.75640166, 404.18708668,
#        365.21963363, 347.80436341, 508.928425  , 141.63920238,
#        618.62694192, 469.37976965, 174.00950502, 196.0931891 ,
#        360.22702117,  29.25994181, 121.14349157, 439.16126203,
#        447.80150825, 169.3311728 , 360.32119204, 155.81674998,
#        167.32603122, 204.3921831 , 365.24847463, 186.33027788,
#        428.00731654, 315.36364511, 181.88570972, 166.71356815,
#        166.4632952 , 373.88684168, 528.12694323, 339.22975117,
#        258.81567118, 120.05950409, 158.68485607, 493.85949276,
#        371.67807186, 163.74168222, 332.83044665, 546.40030172,
#        630.34004603, 234.09311818, 420.09394364, 154.22973882,
#        146.01621589, 521.36868184, 535.16144732, 235.74100681,
#        208.17666582, 165.43077863, 110.2705618 ,  85.37727358,
#        193.83226685, 386.47283779, 134.02947637,  94.46537075,
#        448.37903607, 236.7514742 , 278.08746413, 415.26226084,
#        162.61493913, 408.06406914, 167.10518925, 428.49845758,
#        410.58404531, 473.99437671, 406.97233622, 174.86807314,
#        416.85265835, 337.29887387, 404.17791768, 383.34850331,
#        289.7526874 , 270.14999854, 290.43280521, 462.06482022,
#        176.64303962, 184.05469957, 166.47223672, 346.83546336,
#         29.25994181, 110.65983059, 230.50973729, 447.34808647,
#        460.56970145, 296.82185097,  17.84885773, 679.61405767,
#        391.43661733, 212.28519982, 282.72989886,  32.92082331])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(ytest,ypred)
mse=mean_squared_error(ytest,ypred)
rmse=np.sqrt(mse)
r2=r2_score(ytest,ypred)

print(f'mae : {mae}\nmse : {mse}\nrmse : {rmse}\naccuracy : {r2}')
# Out:
# mae : 14.500809987955337
# mse : 817.8934536841214
# rmse : 28.59883657920583
# accuracy : 0.9703959867454142

# %% [markdown]
# ### We have achieved an Accuracy of 97 % which is good Enough.

# %% [markdown]
# # 2 - Predicting the data using Decision Tree

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor

# %%
def mymodel(model):
   model.fit(xtrain,ytrain)
   ypred=model.predict(xtest)
   print(r2_score(ytest,ypred))

# %%
dt=DecisionTreeRegressor()

# %%
mymodel(dt)
# Out:
# 0.9041733830977027

# %% [markdown]
# ### By using Decision Tree we get an accuracy of 90% which is good but lets check whether we get more accurcy by hyper tunning ploting decision tree

# %% [markdown]
# ### ploting decision tree

# %%
plt.figure(figsize=(25,10))
chart=tree.plot_tree(dt,max_depth=5,feature_names=x.columns,filled=True,fontsize=10)
plt.savefig('abc.jpg')

# %%
Train = dt.score(xtrain,ytrain)
Test = dt.score(xtest,ytest)

# %%
print(f"Train score :{Train}\nTest score : {Test}")
# Out:
# Train score :0.9999993317312936
# Test score : 0.9041733830977027

# %% [markdown]
# ### Train acc is high and Test acc is low
# (low bias high varience)

# %% [markdown]
# ## HPT

# %% [markdown]
# ### i - max_depth

# %%
for i in range(1,50):
    dt1= DecisionTreeRegressor(max_depth=i)
    dt1.fit(xtrain,ytrain)
    ypred=dt1.predict(xtest)
    
    rs=r2_score(ytest,ypred)
    
    print(f"max_depth {i}  r2_score {rs}")
# Out:
# max_depth 1  r2_score 0.5514470168857696
# max_depth 2  r2_score 0.6516646251186102
# max_depth 3  r2_score 0.7837029643421702
# max_depth 4  r2_score 0.7473165615548776
# max_depth 5  r2_score 0.7136655352658297
# max_depth 6  r2_score 0.8594859489377471
# max_depth 7  r2_score 0.8958481052218243
# max_depth 8  r2_score 0.7411481621179358
# max_depth 9  r2_score 0.741353149021031
# max_depth 10  r2_score 0.7842567120317733
# max_depth 11  r2_score 0.7439172401687568
# max_depth 12  r2_score 0.8759904947517191
# max_depth 13  r2_score 0.6904630441149677
# max_depth 14  r2_score 0.8705856438431615
# max_depth 15  r2_score 0.7375557914985114
# max_depth 16  r2_score 0.6476347389353215
# max_depth 17  r2_score 0.8710220282978133
# max_depth 18  r2_score 0.743572527122663
# max_depth 19  r2_score 0.6532081717885234
# max_depth 20  r2_score 0.8658980074924918
# max_depth 21  r2_score 0.7448919133212875
# max_depth 22  r2_score 0.7435584570850321
# max_depth 23  r2_score 0.7431773336881115
# max_depth 24  r2_score 0.6528822136707095
# max_depth 25  r2_score 0.7430925560716222
# max_depth 26  r2_score 0.7458528579931485
# max_depth 27  r2_score 0.8674784167316697
# max_depth 28  r2_score 0.7485887278913788
# max_depth 29  r2_score 0.8723452554592419
# max_depth 30  r2_score 0.7744185311852344
# max_depth 31  r2_score 0.6527913650277208
# max_depth 32  r2_score 0.6548654062814314
# max_depth 33  r2_score 0.8746396376833278
# max_depth 34  r2_score 0.9030324252695133
# max_depth 35  r2_score 0.9076784267768828
# max_depth 36  r2_score 0.8753243220063844
# max_depth 37  r2_score 0.903264567241454
# max_depth 38  r2_score 0.6554555740666248
# max_depth 39  r2_score 0.7456827039579684
# max_depth 40  r2_score 0.6529808183583867
# max_depth 41  r2_score 0.9016063488381153
# max_depth 42  r2_score 0.6923055368320452
# max_depth 43  r2_score 0.8701529061832917
# max_depth 44  r2_score 0.7374544075119183
# max_depth 45  r2_score 0.6506899641827854
# max_depth 46  r2_score 0.9066127137605058
# max_depth 47  r2_score 0.8996553176391655
# max_depth 48  r2_score 0.7459249284202474
# max_depth 49  r2_score 0.7334414381645677

# %%
dt2=DecisionTreeRegressor(max_depth=3)
mymodel(dt2)
# Out:
# 0.7837029643421701

# %%
dt2.score(xtrain,ytrain)
# Out:
# 0.8007611692866369

# %%
dt2.score(xtest,ytest)
# Out:
# 0.7837029643421701

# %% [markdown]
# ### By using Decision Tree Max Depth function we achive the accuracy of 78%

# %% [markdown]
# ### ii - min_samples_split

# %%
for i in range(2,50):
    dt3= DecisionTreeRegressor(min_samples_split=i)
    dt3.fit(xtrain,ytrain)
    ypred=dt3.predict(xtest)
    
    rs=r2_score(ytest,ypred)
    
    print(f"min_samples_split {i}  r2_score {rs}")
# Out:
# min_samples_split 2  r2_score 0.6526991418867396
# min_samples_split 3  r2_score 0.8367095234898483
# min_samples_split 4  r2_score 0.8385078237096104
# min_samples_split 5  r2_score 0.8439583451076548
# min_samples_split 6  r2_score 0.8475612399571495
# min_samples_split 7  r2_score 0.8473494829230734
# min_samples_split 8  r2_score 0.8462372699915138
# min_samples_split 9  r2_score 0.847488898941428
# min_samples_split 10  r2_score 0.8453668577507466
# min_samples_split 11  r2_score 0.8411472810499497
# min_samples_split 12  r2_score 0.8321615618044956
# min_samples_split 13  r2_score 0.8345931361901547
# min_samples_split 14  r2_score 0.8316701480666139
# min_samples_split 15  r2_score 0.8308461849309605
# min_samples_split 16  r2_score 0.8315990994805194
# min_samples_split 17  r2_score 0.8316500515526282
# min_samples_split 18  r2_score 0.8499781025526659
# min_samples_split 19  r2_score 0.8542434642544168
# min_samples_split 20  r2_score 0.8548803813294599
# min_samples_split 21  r2_score 0.8548803813294599
# min_samples_split 22  r2_score 0.8504652016318861
# min_samples_split 23  r2_score 0.8491493354966965
# min_samples_split 24  r2_score 0.846813630799895
# min_samples_split 25  r2_score 0.8457706925374616
# min_samples_split 26  r2_score 0.8457706925374616
# min_samples_split 27  r2_score 0.8441727375234522
# min_samples_split 28  r2_score 0.8441727375234522
# min_samples_split 29  r2_score 0.8441727375234522
# min_samples_split 30  r2_score 0.8441727375234522
# min_samples_split 31  r2_score 0.8441727375234522
# min_samples_split 32  r2_score 0.8428361094907146
# min_samples_split 33  r2_score 0.843532338694595
# min_samples_split 34  r2_score 0.843532338694595
# min_samples_split 35  r2_score 0.8421679536117644
# min_samples_split 36  r2_score 0.8422620071308807
# min_samples_split 37  r2_score 0.8343985825956104
# min_samples_split 38  r2_score 0.8343985825956104
# min_samples_split 39  r2_score 0.8343985825956104
# min_samples_split 40  r2_score 0.8343985825956104
# min_samples_split 41  r2_score 0.8315788006981221
# min_samples_split 42  r2_score 0.8315788006981222
# min_samples_split 43  r2_score 0.8315788006981221
# min_samples_split 44  r2_score 0.8315788006981221
# min_samples_split 45  r2_score 0.8315788006981222
# min_samples_split 46  r2_score 0.8315788006981222
# min_samples_split 47  r2_score 0.8315788006981221
# min_samples_split 48  r2_score 0.8213706750570768
# min_samples_split 49  r2_score 0.821370675057077

# %%
dt4=DecisionTreeRegressor(min_samples_split=4)
mymodel(dt4)
# Out:
# 0.8403423666417927

# %%
dt4.score(xtrain,ytrain)
# Out:
# 0.972215862100051

# %%
dt4.score(xtest,ytest)
# Out:
# 0.8403423666417927

# %% [markdown]
# ### By using Decision Tree Min Sample Split function we achive the accuracy of 84%

# %% [markdown]
# ### iii - min_samples_leaf

# %%
for i in range(1,50):
    dt5= DecisionTreeRegressor(min_samples_leaf=i)
    dt5.fit(xtrain,ytrain)
    ypred=dt5.predict(xtest)
    
    rs=r2_score(ytest,ypred)
    
    print(f"min_samples_split {i}  r2_score {rs}")
# Out:
# min_samples_split 1  r2_score 0.8706933915514796
# min_samples_split 2  r2_score 0.845515669385869
# min_samples_split 3  r2_score 0.8643239162460259
# min_samples_split 4  r2_score 0.8788489736295327
# min_samples_split 5  r2_score 0.8882869604283694
# min_samples_split 6  r2_score 0.8801443508178857
# min_samples_split 7  r2_score 0.9034573044444353
# min_samples_split 8  r2_score 0.9179118849013054
# min_samples_split 9  r2_score 0.8953920181891402
# min_samples_split 10  r2_score 0.895507127253411
# min_samples_split 11  r2_score 0.8997582565389802
# min_samples_split 12  r2_score 0.9004103386296692
# min_samples_split 13  r2_score 0.8972778028349776
# min_samples_split 14  r2_score 0.8873557612482292
# min_samples_split 15  r2_score 0.8843636747032732
# min_samples_split 16  r2_score 0.8924852373568651
# min_samples_split 17  r2_score 0.8918214880617489
# min_samples_split 18  r2_score 0.8938349522466633
# min_samples_split 19  r2_score 0.8850329803134712
# min_samples_split 20  r2_score 0.87084149036245
# min_samples_split 21  r2_score 0.8741586734372286
# min_samples_split 22  r2_score 0.8741586734372286
# min_samples_split 23  r2_score 0.8749546703263644
# min_samples_split 24  r2_score 0.8615631652322732
# min_samples_split 25  r2_score 0.8512317052322179
# min_samples_split 26  r2_score 0.8512317052322178
# min_samples_split 27  r2_score 0.8463752870764651
# min_samples_split 28  r2_score 0.8314015592996228
# min_samples_split 29  r2_score 0.8278973789567563
# min_samples_split 30  r2_score 0.8325362680562528
# min_samples_split 31  r2_score 0.813441516412597
# min_samples_split 32  r2_score 0.8134415164125972
# min_samples_split 33  r2_score 0.813441516412597
# min_samples_split 34  r2_score 0.813441516412597
# min_samples_split 35  r2_score 0.8134415164125971
# min_samples_split 36  r2_score 0.8134415164125971
# min_samples_split 37  r2_score 0.8150946550322047
# min_samples_split 38  r2_score 0.8141651929974287
# min_samples_split 39  r2_score 0.8141651929974287
# min_samples_split 40  r2_score 0.8130757339868844
# min_samples_split 41  r2_score 0.8098326154037964
# min_samples_split 42  r2_score 0.8098326154037964
# min_samples_split 43  r2_score 0.8056624535666006
# min_samples_split 44  r2_score 0.8056624535666007
# min_samples_split 45  r2_score 0.7712328493498576
# min_samples_split 46  r2_score 0.7734483818697546
# min_samples_split 47  r2_score 0.7731380187753205
# min_samples_split 48  r2_score 0.7692645751251548
# min_samples_split 49  r2_score 0.694119847707718

# %%
dt6=DecisionTreeRegressor(min_samples_leaf=5)
mymodel(dt6)
# Out:
# 0.8882869604283695

# %%
dt6.score(xtrain,ytrain)
# Out:
# 0.9136044692959997

# %%
dt6.score(xtest,ytest)
# Out:
# 0.8882869604283695

# %% [markdown]
# ### By using Decision Tree min_samples_leaf function we achive the accuracy of 89%

# %% [markdown]
# # 3 - Predicting the data using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
rfr = RandomForestRegressor(n_estimators=100, max_depth=5)

rfr.fit(xtrain, ytrain)
ypred = rfr.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print('MSE:', mean_squared_error(ytest, ypred))
print('MAE:', mean_absolute_error(ytest, ypred))
print('r2_score:', r2_score(ytest, ypred))
# Out:
# MSE: 1961.0058501095996
# MAE: 26.359669820040946
# r2_score: 0.9278826353419685

# %% [markdown]
# ### By using Random Forest we get 93% of accuracy.

# %% [markdown]
# # CONCLUSION

# %%
print(("*")*125)
print("\tBased on the above accuracy scores, we should go ahead with Linear regression, Random forest. The best predictive model for the above dataset is Linear regressoin and its Accuracy is given by accuracy 97%. ")
print(("*")*125)
# Out:
# *****************************************************************************************************************************
# 	Based on the above accuracy scores, we should go ahead with Linear regression, Random forest. The best predictive model for the above dataset is Linear regressoin and its Accuracy is given by accuracy 97%.
# *****************************************************************************************************************************
